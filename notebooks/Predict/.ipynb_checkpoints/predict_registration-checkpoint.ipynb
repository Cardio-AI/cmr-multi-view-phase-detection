# %% [markdown]
# # Import and Setup

# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

import random
from collections import Counter
import matplotlib.pyplot as plt
#plt.rcParams.update({'font.size': 30})
import pandas as pd
import numpy as np
import SimpleITK as sitk 
import csv

import scipy.interpolate
from scipy.interpolate import interp1d


from src.utils.Notebook_imports import *
from src.data.Preprocess import clip_quantile
from src.data.Dataset import load_phase_reg_exp
from src.visualization.Visualize import plot_dir_norm
from src.visualization.Visualize import show_2D_or_3D

import tensorflow as tf
from src.models.KerasLayers import get_angle_tf,get_focus_tf,get_idxs_tf, minmax_lambda, flow2direction_lambda

from ipywidgets import interact, interact_manual
import ipywidgets as widgets
from IPython.core.display import display, HTML
from ipyfilechooser import FileChooser

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/test/cmr-multi-view-phase-detection
# /tmp/ipykernel_37264/2798601717.py:32: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
def get_file(path):
    files = sorted(glob.glob(path))
    if len(files) > 0:
        print(f"Found {len(files)} file in {path}.\nFirst file:{files[0]}\n")
    else:
        print(f"Found no files in {path}")
    return files

def get_df(path_chooser, file_name='dataset_information.csv'):
    dataset_path = path_chooser.selected
    dataset_info_path = get_file(os.path.join(dataset_path, file_name))
    df = pd.read_csv(dataset_info_path[0])
    # Find the first row with NaN values
    index_of_nan = df.index[df.isnull().any(axis=1)].tolist()

    # Stop reading at the first row with NaN values
    # if index_of_nan:
    #     df = df.iloc[:index_of_nan[0]]
    return df

# %%
from src.visualization.Visualize import plot_pfd_per_phase_as_violin
def plot_error_as_violin(df_, exp_path = None, y_range=[0,10], plot = True):
    import seaborn as sb
    if type(y_range) == type(1):
        y_range = [0, y_range]
    sb.set_context('paper')
    sb.set(font_scale=2)
    if plot:
        # _ = df_.plot(kind='box')
        ax = sb.violinplot(data=df_)
        ax = sb.stripplot(data=df_, ax=ax)
        ax.set_ylim(y_range[0], y_range[1])
        _ = ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    if y_range[1] - y_range[0] < 5: 
        pd.options.display.float_format = "{:,.4f}".format
    else: 
        pd.options.display.float_format = "{:,.2f}".format
    df_summarized = pd.concat([df_.mean(axis=0), df_.std(axis=0), df_.median(axis=0)], axis=1)
    df_summarized.columns = ['mean', 'SD', 'median']
    if plot:
        print('mean overall\n', df_summarized.mean())
        # print('mean first three phases\n',df_summarized.iloc[:3].mean())
        print(df_summarized)
        latex_output = " & ".join([f"{df_summarized.loc[col, 'mean']:.2f} $\\pm$ {df_summarized.loc[col, 'SD']:.2f}" for col in df_summarized.index]) + " \\\\"
        print("\nLaTeX Output:\n", latex_output)  # Output the formatted line
    
    if exp_path is not None: plt.savefig(os.path.join(exp_path, 'pFD_violin.png'))
    return df_summarized

# %% [markdown]
# ## Select path to dataset

# %%
path_chooser_dataset = FileChooser(os.path.join(os.getcwd(),''), '')
display(path_chooser_dataset)
# Out:
# FileChooser(path='/mnt/ssd/git/test/cmr-multi-view-phase-detection', filename='', title='HTML(value='', layout…

# %%
dataset_df_str = "phases.csv"

dataset_path = path_chooser_dataset.selected

dataset_info_df = get_df(path_chooser_dataset, file_name=dataset_df_str)
dataset_info_df.columns = dataset_info_df.columns.str.lower()
dataset_info_df
# Out:
# Found 1 file in /mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv.
# First file:/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv
#      unnamed: 0      patient  ed#  ms#  es#  pf#  md# disease unnamed: 8  \
# 0             0  001_SA_CINE   23    4    8   15   20     NOR        NaN
# 1             1  002_SA_CINE   23    5    8   13   20     NOR        NaN
# 2             2  003_SA_CINE   23    4    8   14   19     NOR        NaN
# 3             3  004_SA_CINE   23    3    7   11   21     NOR        NaN
# 4             4  005_SA_CINE   23    3    7   12   19     NOR        NaN
# ..          ...          ...  ...  ...  ...  ...  ...     ...        ...
# 195         195  196_SA_CINE   28    4   11   18   25     TRI        NaN
# 196         196  197_SA_CINE   27    3   12   16   21     TRI        NaN
# 197         197  198_SA_CINE   23    3    6   13   20     TRI        NaN
# 198         198  199_SA_CINE   23    4    9   14   20     TRI        NaN
# 199         199  200_SA_CINE   24    4    8   13   18     TRI        NaN
#
#     unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 195        NaN
# 196        NaN
# 197        NaN
# 198        NaN
# 199        NaN
#
# [200 rows x 10 columns]

# %% [markdown]
# ## Select path to model/experiment

# %%
path_chooser = FileChooser(os.path.join(os.getcwd(),''), '')
display(path_chooser)
# Out:
# FileChooser(path='/mnt/ssd/git/test/cmr-multi-view-phase-detection', filename='', title='HTML(value='', layout…

# %%
model_path = path_chooser.selected

# %% [markdown]
# # Predict

# %%
from src.utils.Utils_io import get_json
cfg_files = get_json('config/config.json', model_path)
dataset_files = get_json('config/dataset.json', model_path)

patients_txt_file = os.path.join(model_path, 'pred', 'patients.txt')
if os.path.exists(patients_txt_file):
    import os
    # removing previous inference files using the os.remove() method
    os.remove(patients_txt_file)
# Out:
# Config file: ['/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/f0/config/config.json']
# Config file: ['/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/f0/config/dataset.json']

# %%
from src.models.predict_phase_reg_model import CMRPhaseDetector
num_examples = 0   # <-- set to 1 if you want to store random example files as nrrd.

# predict for each fold
for cfg, data_json in zip(cfg_files, dataset_files):
    cmr_phase_predictor = CMRPhaseDetector(model_config=cfg, data_info_path=data_json, data_root=dataset_path, exp_path=model_path)
    
    cmr_phase_predictor.predict(number_of_examples=num_examples)
    
    cmr_phase_predictor.predict_phase_from_deformable()
# Out:
# 2026-07-28 16:27:12,849 INFO -------------------- Start --------------------
# 2026-07-28 16:27:12,849 INFO Working directory: /mnt/ssd/git/test/cmr-multi-view-phase-detection.
# 2026-07-28 16:27:12,849 INFO Log file: ./logs/dataset_name/sub-identifier/f0.log
# 2026-07-28 16:27:12,850 INFO Log level for console: INFO
# 2026-07-28 16:27:12,850 INFO Loaded config for experiment: dataset_name/sub-identifier/f0
# 2026-07-28 16:27:12,851 INFO No dataframe for splitting provided. Will use all files for train and validation
# 2026-07-28 16:27:12,851 INFO Selected 74 of 74 files
# 2026-07-28 16:27:12,851 INFO sax-midslice train CMR: 74, sax-midslicetrain masks: 74
# 2026-07-28 16:27:12,851 INFO sax-midslice val CMR: 74, sax-midslice val masks: 74
# 2026-07-28 16:27:12,851 INFO Split into chunks of:
# 2026-07-28 16:27:12,852 INFO sax-midslice train CMR: 8, sax-midslice train masks: 8
# 2026-07-28 16:27:12,852 INFO sax-midslice val CMR: 8, sax-midslice val masks: 8
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/test/cmr-multi-view-phase-detection
# ['/gpu:0']
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# /mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/sax-midslice *CINE_midslice.nii.gz
# build u-net for input shape:  (None, 224, 224, 2)
# Shape Input Tensor: (None, 40, 224, 224, 2)
# 2026-07-28 16:27:13,497 INFO Trying to load the model weights
# 2026-07-28 16:27:13,497 INFO work dir: /mnt/ssd/git/test/cmr-multi-view-phase-detection
# 2026-07-28 16:27:13,498 INFO model weights dir: /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/f0/model/model.h5
# 2026-07-28 16:27:13,539 INFO loaded model weights as h5 file
# 2026-07-28 16:27:13,540 INFO ***********  processing junk: 0 of 8
# 2026-07-28 16:27:13,540 INFO Create DataGenerator
# 2026-07-28 16:27:13,540 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:13,541 INFO No augmentation
# 2026-07-28 16:27:13,541 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/001_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:13,543 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:13,543 INFO params of generator:
# 2026-07-28 16:27:13,543 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# Unet output shape: (None, 40, 224, 224, 16)
# Flowfield shape: (None, 40, 224, 224, 2)
# Transformed shape : (None, 40, 224, 224, 1)
# flow features inkl directions shape: (None, 40, 224, 224, 1)
# flow features after downsample/gap layer: (None, 40, 1)
# Shape after final conv layer: (None, 40, 5)
# added loss: ssim
# 2026-07-28 16:27:17,177 INFO ***********  processing junk: 1 of 8
# 2026-07-28 16:27:17,178 INFO Create DataGenerator
# 2026-07-28 16:27:17,178 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:17,178 INFO No augmentation
# 2026-07-28 16:27:17,178 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/011_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:17,181 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:17,181 INFO params of generator:
# 2026-07-28 16:27:17,181 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:19,442 INFO ***********  processing junk: 2 of 8
# 2026-07-28 16:27:19,443 INFO Create DataGenerator
# 2026-07-28 16:27:19,443 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:19,443 INFO No augmentation
# 2026-07-28 16:27:19,443 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/021_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:19,445 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:19,445 INFO params of generator:
# 2026-07-28 16:27:19,445 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:21,717 INFO ***********  processing junk: 3 of 8
# 2026-07-28 16:27:21,717 INFO Create DataGenerator
# 2026-07-28 16:27:21,717 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:21,718 INFO No augmentation
# 2026-07-28 16:27:21,718 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/031_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:21,720 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:21,720 INFO params of generator:
# 2026-07-28 16:27:21,720 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:24,071 INFO ***********  processing junk: 4 of 8
# 2026-07-28 16:27:24,071 INFO Create DataGenerator
# 2026-07-28 16:27:24,071 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:24,071 INFO No augmentation
# 2026-07-28 16:27:24,072 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/041_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:24,074 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:24,074 INFO params of generator:
# 2026-07-28 16:27:24,074 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:26,133 INFO ***********  processing junk: 5 of 8
# 2026-07-28 16:27:26,133 INFO Create DataGenerator
# 2026-07-28 16:27:26,133 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:26,134 INFO No augmentation
# 2026-07-28 16:27:26,134 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/051_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:26,136 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:26,136 INFO params of generator:
# 2026-07-28 16:27:26,136 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:28,209 INFO ***********  processing junk: 6 of 8
# 2026-07-28 16:27:28,210 INFO Create DataGenerator
# 2026-07-28 16:27:28,210 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:28,210 INFO No augmentation
# 2026-07-28 16:27:28,211 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/061_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:28,212 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:28,213 INFO params of generator:
# 2026-07-28 16:27:28,213 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:30,462 INFO ***********  processing junk: 7 of 8
# 2026-07-28 16:27:30,462 INFO Create DataGenerator
# 2026-07-28 16:27:30,463 INFO Datagenerator created with:
#  shape: [224, 224]
#  spacing: [1, 1]
#  batchsize: 1
#  Scaler: Standard
#  Images: 4
#  Augment: False
#  Thread workers: 8
# 2026-07-28 16:27:30,463 INFO No augmentation
# 2026-07-28 16:27:30,463 INFO first file: /mnt/ssd/data/01-3-mnms-2/imported_sax_3d_split/training/sax-mid-slice/sax-midslice/071_sa_cine_midslice.nii.gz
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/data/PhaseGenerators.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if self.ISNIFTI: self.DF_METADATA['patient'] = self.DF_METADATA['patient'].str.zfill(3)
# 2026-07-28 16:27:30,465 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2026-07-28 16:27:30,465 INFO params of generator:
# 2026-07-28 16:27:30,465 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'Standard'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [1, 1]), ('SEED', 42), ('DIM', [224, 224]), ('BATCHSIZE', 1), ('MASK_VALUES', [1, 2, 3]), ('N_CLASSES', 3), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-3, 3]), ('T_SHAPE', 40), ('T_SPACING', 1), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', False), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-3, 3]), ('RESAMPLE_T', False), ('ROTATE', False), ('TRANSLATE', True), ('ADD_SOFTMAX', False), ('SOFTMAX_AXIS', 0), ('ROLL2SEPTUM', False), ('ROLL2LV', False), ('PRETRAINED_SEG', False), ('NNUNET_SEG', False), ('CMR3D', False), ('IN_MEMORY', False), ('ISNIFTI', True), ('STARTID', 0), ('METADATA_FILE', '/mnt/ssd/data/01-3-MnMs-2/imported_SAX_3D_split/training/sax-mid-slice/phases.csv')]
# 2026-07-28 16:27:31,373 INFO saved as:
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/pred/gtpred_fold0007.npy
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/pred/patients.txt
#  example patients processed!
# ['/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0000.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0001.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0002.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0003.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0004.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0005.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0006.npy', '/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/moved/vects_f0007.npy']
# 2026-07-28 16:27:31,643 INFO vects_nda: (74, 40, 224, 224, 2)
# 2026-07-28 16:27:31,644 INFO Found no masks, will use self-supervised masking.
# files loaded 0.270 s, continue with deformable2direction2phase
# processing patient : 0
# processing patient : 20
# processing patient : 40
# processing patient : 60
# /home/sarah/.conda/envs/cmr-phases-test/lib/python3.8/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# /home/sarah/.conda/envs/cmr-phases-test/lib/python3.8/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/visualization/Visualize.py:33: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_summarized = pd.concat([df_pfd.mean(axis=0), df_pfd.std(axis=0), df_pfd.median(axis=0)], axis=1)
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/visualization/Visualize.py:33: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_summarized = pd.concat([df_pfd.mean(axis=0), df_pfd.std(axis=0), df_pfd.median(axis=0)], axis=1)
# /mnt/ssd/git/test/cmr-multi-view-phase-detection/src/visualization/Visualize.py:33: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_summarized = pd.concat([df_pfd.mean(axis=0), df_pfd.std(axis=0), df_pfd.median(axis=0)], axis=1)
# mean overall
#  mean     1.95
# SD       2.21
# median   1.40
# dtype: float32
#     mean   SD  median
# ED  1.69 2.44    1.00
# MS  1.61 1.87    1.00
# ES  2.19 1.94    2.00
# PF  2.50 2.34    2.00
# MD  1.78 2.47    1.00
# [    ED  MS  ES  PF  MD                          patient
#  0   21   1   8  15  18  0_001_SA_CINE_midslice.nii.gz\n
#  1   22   3   8  14  20  0_002_SA_CINE_midslice.nii.gz\n
#  2   22   3   7   9  19  0_003_SA_CINE_midslice.nii.gz\n
#  3   23   1   8  11  21  0_004_SA_CINE_midslice.nii.gz\n
#  4    0   2   6  12  20  0_005_SA_CINE_midslice.nii.gz\n
#  ..  ..  ..  ..  ..  ..                              ...
#  69  14  20  29   7  10  0_070_SA_CINE_midslice.nii.gz\n
#  70  29   4  11  12  27  0_071_SA_CINE_midslice.nii.gz\n
#  71  18  27  13  16  17  0_072_SA_CINE_midslice.nii.gz\n
#  72  20  29  13  14  17  0_073_SA_CINE_midslice.nii.gz\n
#  73  29   5  10  18  27  0_074_SA_CINE_midslice.nii.gz\n
#
#  [74 rows x 6 columns],
#      ED  MS  ES  PF  MD                          patient
#  0   23   4   8  15  20  0_001_SA_CINE_midslice.nii.gz\n
#  1   23   5   8  13  20  0_002_SA_CINE_midslice.nii.gz\n
#  2   23   4   8  14  19  0_003_SA_CINE_midslice.nii.gz\n
#  3   23   3   7  11  21  0_004_SA_CINE_midslice.nii.gz\n
#  4   23   3   7  12  19  0_005_SA_CINE_midslice.nii.gz\n
#  ..  ..  ..  ..  ..  ..                              ...
#  69  19  25  29   5  14  0_070_SA_CINE_midslice.nii.gz\n
#  70  29   4  11  17  26  0_071_SA_CINE_midslice.nii.gz\n
#  71  28   3  10  16  23  0_072_SA_CINE_midslice.nii.gz\n
#  72  29   4   7  17  24  0_073_SA_CINE_midslice.nii.gz\n
#  73  29   5  10  17  27  0_074_SA_CINE_midslice.nii.gz\n
#
#  [74 rows x 6 columns],
#        ED   MS   ES   PF   MD                          patient
#  0   2.00 3.00 0.00 0.00 2.00  0_001_SA_CINE_midslice.nii.gz\n
#  1   1.00 2.00 0.00 1.00 0.00  0_002_SA_CINE_midslice.nii.gz\n
#  2   1.00 1.00 1.00 5.00 0.00  0_003_SA_CINE_midslice.nii.gz\n
#  3   0.00 2.00 1.00 0.00 0.00  0_004_SA_CINE_midslice.nii.gz\n
#  4   2.00 1.00 1.00 0.00 1.00  0_005_SA_CINE_midslice.nii.gz\n
#  ..   ...  ...  ...  ...  ...                              ...
#  69  5.00 5.00 0.00 2.00 4.00  0_070_SA_CINE_midslice.nii.gz\n
#  70  0.00 0.00 0.00 5.00 1.00  0_071_SA_CINE_midslice.nii.gz\n
#  71 10.00 6.00 3.00 0.00 6.00  0_072_SA_CINE_midslice.nii.gz\n
#  72  9.00 5.00 6.00 3.00 7.00  0_073_SA_CINE_midslice.nii.gz\n
#  73  0.00 0.00 0.00 1.00 0.00  0_074_SA_CINE_midslice.nii.gz\n
#
#  [74 rows x 6 columns],
#  <tf.Tensor: shape=(74, 5), dtype=float32, numpy=
#  array([[ 2.,  3.,  0.,  0.,  2.],
#         [ 1.,  2.,  0.,  1.,  0.],
#         [ 1.,  1.,  1.,  5.,  0.],
#         [ 0.,  2.,  1.,  0.,  0.],
#         [ 2.,  1.,  1.,  0.,  1.],
#         [ 0.,  0.,  1.,  4.,  0.],
#         [10.,  8.,  5.,  1., 10.],
#         [ 0.,  1.,  1.,  2.,  0.],
#         [ 0.,  0.,  2.,  2.,  1.],
#         [ 0.,  2.,  3.,  3.,  0.],
#         [ 0.,  1.,  1.,  1.,  0.],
#         [ 1.,  1.,  2.,  0.,  1.],
#         [ 1.,  3.,  1.,  4.,  0.],
#         [ 0.,  0.,  5.,  1.,  1.],
#         [ 5.,  1.,  1.,  1.,  0.],
#         [ 0.,  5.,  3.,  1.,  4.],
#         [ 1.,  2.,  1.,  0.,  0.],
#         [ 0.,  1.,  2.,  1.,  1.],
#         [ 1.,  5.,  2.,  2.,  0.],
#         [ 1.,  0.,  2.,  5., 12.],
#         [ 1.,  3.,  2.,  8.,  1.],
#         [ 0.,  0.,  0.,  1.,  0.],
#         [ 0.,  5.,  7.,  0.,  1.],
#         [ 0.,  0.,  2.,  1.,  1.],
#         [ 0.,  0.,  5.,  0.,  1.],
#         [ 0.,  0.,  1.,  7.,  2.],
#         [ 0.,  0.,  3.,  0.,  0.],
#         [ 1.,  1.,  2.,  3.,  0.],
#         [ 3.,  2.,  2.,  5.,  4.],
#         [ 1.,  1.,  1.,  2.,  1.],
#         [ 1.,  1.,  1.,  4.,  0.],
#         [ 1.,  1.,  1.,  5.,  0.],
#         [ 1.,  1.,  1.,  2.,  0.],
#         [ 2.,  1.,  3.,  4.,  0.],
#         [ 0.,  0.,  1.,  6.,  1.],
#         [ 1.,  0.,  3.,  0.,  1.],
#         [ 0.,  1.,  5.,  6.,  1.],
#         [ 4.,  0.,  0.,  1.,  1.],
#         [ 1.,  1.,  3.,  1.,  6.],
#         [ 0.,  3.,  0.,  3.,  1.],
#         [ 2.,  3.,  5.,  4.,  1.],
#         [ 3.,  1.,  2.,  4.,  0.],
#         [ 0.,  1.,  3.,  0.,  1.],
#         [ 1.,  1.,  1.,  0.,  0.],
#         [ 1.,  1.,  2.,  7.,  2.],
#         [ 1.,  1.,  2.,  1.,  1.],
#         [ 1.,  2.,  0.,  4.,  1.],
#         [ 1.,  1.,  0.,  1.,  2.],
#         [ 3.,  1.,  4.,  1.,  0.],
#         [ 2.,  1.,  0.,  4.,  2.],
#         [ 0.,  0.,  4.,  1.,  1.],
#         [ 0.,  1.,  0.,  3.,  1.],
#         [ 3.,  0.,  0.,  4.,  5.],
#         [ 0.,  1.,  1.,  1.,  1.],
#         [ 1.,  1.,  1.,  2.,  0.],
#         [ 3.,  1.,  3.,  1.,  5.],
#         [ 0.,  1.,  1.,  5.,  2.],
#         [ 1.,  0.,  0.,  4.,  1.],
#         [ 3.,  0.,  6.,  9.,  4.],
#         [ 1.,  2.,  0.,  0.,  2.],
#         [ 3.,  1.,  2.,  0.,  4.],
#         [11.,  8.,  4.,  8.,  8.],
#         [ 0.,  1.,  5.,  1.,  0.],
#         [ 2.,  4.,  8.,  5.,  3.],
#         [ 1.,  1.,  4.,  1.,  0.],
#         [ 5.,  1.,  6.,  2.,  0.],
#         [ 2.,  0.,  3.,  1.,  1.],
#         [ 1.,  1.,  3.,  7.,  5.],
#         [ 6.,  6.,  5.,  0.,  6.],
#         [ 5.,  5.,  0.,  2.,  4.],
#         [ 0.,  0.,  0.,  5.,  1.],
#         [10.,  6.,  3.,  0.,  6.],
#         [ 9.,  5.,  6.,  3.,  7.],
#         [ 0.,  0.,  0.,  1.,  0.]], dtype=float32)>,
#  array([25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 30, 30, 30, 30,
#         30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 18, 30, 30, 30, 30,
#         30, 30, 30, 30, 30, 30, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#         25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25,
#         25, 30, 30, 30, 30, 30])]

# %% [markdown]
# ## Evaluate

# %%
cfd_path = get_file(os.path.join(model_path, 'cfd.csv'))
gt_path = get_file(os.path.join(model_path, 'gt_phases.csv'))
pred_path = get_file(os.path.join(model_path, 'pred_phases.csv'))

gt_df = pd.read_csv(gt_path[0])
cfd_df = pd.read_csv(cfd_path[0])
pred_df = pd.read_csv(pred_path[0])
# Out:
# Found 1 file in /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/cfd.csv.
# First file:/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/cfd.csv
#
# Found 1 file in /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/gt_phases.csv.
# First file:/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/gt_phases.csv
#
# Found 1 file in /mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/pred_phases.csv.
# First file:/mnt/ssd/git/test/cmr-multi-view-phase-detection/exp/dataset_name/sub-identifier/2026-07-28_12_51/pred_phases.csv

# %%
# If you have already a cfd file with results in the folder you can create violin plots of  wished phases here
phases = ['ED',  'ES']  #  ['ED', 'MS', 'ES', 'PF', 'MD'] or ['ED', 'ES']
plot_error_as_violin(cfd_df[phases], y_range= 14)
plt.show()
# Out:
# mean overall
#  mean     1.94
# SD       2.19
# median   1.50
# dtype: float64
#     mean   SD  median
# ED  1.69 2.44    1.00
# ES  2.19 1.94    2.00
#
# LaTeX Output:
#  1.69 $\pm$ 2.44 & 2.19 $\pm$ 1.94 \\
# /home/sarah/.conda/envs/cmr-phases-test/lib/python3.8/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# /home/sarah/.conda/envs/cmr-phases-test/lib/python3.8/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# # Predict for different Experiments
